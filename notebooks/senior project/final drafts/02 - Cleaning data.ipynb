# %%
import re
import pandas as pd
import numpy as np
import csv
import json
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\clu\\Documents\\cal poly\\research\\Kelly Bodwin\\notebooks\\final drafts'

# %%
df = pd.read_csv(open("..//..//data//Weekly_data.csv", encoding = "utf-8"))

# %%
df = pd.read_csv(open("..//..//data//Weekly_data_clean.csv", encoding = "utf-8"))

# %%
df.head()
# Out:
#                                              Artists            Name  \
# 0                                              Drake  In My Feelings
# 1                  6ix9ine, Nicki Minaj, Murda Beatz            FEFE
# 2                                  Maroon 5, Cardi B  Girls Like You
# 3  DJ Khaled, Justin Bieber, Chance The Rapper, Q...      No Brainer
# 4                                        Post Malone      Better Now
#
#    Weekly rank  Peak position  Weeks on chart        Week            Date  \
# 0            1            1.0             5.0  2018-08-11   June 29, 2018
# 1            3            3.0             2.0  2018-08-11   July 22, 2018
# 2            4            3.0            10.0  2018-08-11    May 30, 2018
# 3            5            NaN             NaN  2018-08-11   July 27, 2018
# 4            6            5.0            14.0  2018-08-11  April 27, 2018
#
#                                                Genre  \
# 0  Toronto,Pop,Trap,Quality Control Music,Florida...
# 1  Pop,Universal,YMCMB,Republic Records,Trap,New ...
# 2  New York,Warner Bros.,Atlantic Records,Intersc...
# 3  Capitol Records,Motown,Universal,R&;B,Electro-...
# 4  R&;B,Republic Records,Pop,Trap,New York,Cloud ...
#
#                                      Writing Credits  \
# 0  Phil triggaman price, Orville bugs can can hal...
# 1   Baka, Cubeatz, Shotti3, Nicki minaj, Murda beatz
# 2  Gian stone, Cirkut, Cardi b, Starrah, Adam lev...
# 3  Dj khaled, Justin bieber, Quavo, Chance the ra...
# 4  Kaan gunesberk, William walsh, Carl rosen, Bil...
#
#                                               Lyrics  Songwriter
# 0  In My Feelings \nTrap, TrapMoneyBenny\nThis sh...       False
# 1  FEFE \nIt's fucking TR3YWAY!\nKing of New York...       False
# 2  Girls Like You Remix \nSpent 24 hours, I need ...        True
# 3  No Brainer \nWe the Best Music!\nAnother one!\...       False
# 4  Better Now \nYou prolly think that you are bet...       False

# %%
def isnull(x):
    """
    """
    return x != x

def clean_lyric(lyric, uni_replace):
    
    repl = {"\[.+?\]": "", 
            "\s{2,}": "\n", 
            "lyrics": "", 
            "\(": "", 
            "\)": "",
            "\<u\+0092\>": "'",
            "\<u\+0097\>": "-",
            "\<u\+00..\>": "",
            " '{0,}": " ",
            "in'{1} ": "ing ",
            "\.{0,} ": " ",
            " \.{0,}": " ",
            ' "{0,}': " ",
            '"{0,} ': " ",
            }
    
    for i in repl:
        lyric = re.sub(i, repl[i], lyric, flags = re.I | re.S)
        
    for i in uni_replace:
        lyric = re.sub(i, "", lyric, flags = re.I | re.S)
        
    
    
    return lyric

# %%
filler = [" and ", " featuring ", " & ", " x ", " / "]
repl = {"(\"|”).+?(\"|”)": "", "\s+": " ", "\s,": ","}
textcols = ["Artists", "Name", "Genre", "Writing Credits", "Lyrics"]
unicode_replace  = json.load(open("..//..//data//unicoderemove.json", "r"))

for i in textcols:
    for j in range(len(df)):
        if not isnull(df.loc[j, i]):
            if i == "Artists":
                for k in filler:
                    df.loc[j, i] = re.sub(k, ", ", df.loc[j, i], flags = re.I | re.S)
            elif i == "Lyrics":
                df.loc[j, i] = clean_lyric(df.loc[j, i], unicode_replace)
            else:
                for k in repl:
                    df.loc[j, i] = re.sub(k, repl[k], df.loc[j, i], flags = re.I | re.S)
                df.loc[j, i] = df.loc[j, i].strip()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b00b978bc6ff> in <module>
#      14             else:
#      15                 for k in repl:
# ---> 16                     df.loc[j, i] = re.sub(k, repl[k], df.loc[j, i], flags = re.I | re.S)
#      17                 df.loc[j, i] = df.loc[j, i].strip()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     613                 # scalar
#     614                 for item in labels:
# --> 615                     setter(item, value)
#     616
#     617         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     536                     # set the item, possibly having a dtype change
#     537                     s._consolidate_inplace()
# --> 538                     s = s.copy()
#     539                     s._data = s._data.setitem(indexer=pi, value=v)
#     540                     s._maybe_update_cacher(clear=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5112         dtype: object
#    5113         """
# -> 5114         data = self._data.copy(deep=deep)
#    5115         return self._constructor(data).__finalize__(self)
#    5116
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#    3918             new_axes = list(self.axes)
#    3919         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3920                           do_integrity_check=False)
#    3921
#    3922     def as_array(self, transpose=False, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#     776         values = self.values
#     777         if deep:
# --> 778             values = values.copy()
#     779         return self.make_block_same_class(values)
#     780
#
# KeyboardInterrupt:

# %%
# df[df.Name == "No Lie"].reset_index(drop = True).loc[0].Lyrics

# %% [markdown]
# ## Add songwriters

# %%
writers = json.load(open("..//..//data//composers.json", "r"))

# %%
composers = []
for i in range(len(df)):
    for j in writers:
        if not isnull(df.loc[i, "Writing Credits"]):
            if re.search(j, df.loc[i, "Writing Credits"], flags = re.I | re.S) is not None:
                if re.search(j, df.loc[i, "Artists"], flags = re.I | re.S) is None:
                    composers.append(True)
                    break
    else:
        composers.append(False)

# %%
len(composers)
# Out:
# 49500

# %%
df["Songwriter"] = np.array(composers)

# we drop NA's here for convenience now....will fix later
df = df[df.Lyrics == df.Lyrics]
df.to_csv("..//..//data//Weekly_data_clean.csv", index = False)
