# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
#path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"
path = "C:\\Users\\Sam\\Desktop\\song authorship"

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "first draft"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(2000, 20))
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master 43456c4] first draft
#  35 files changed, 458285 insertions(+), 15360 deletions(-)
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft.html
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/__packages
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-1_e0737ee8f71e526ad3f67d61921f2626.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-1_e0737ee8f71e526ad3f67d61921f2626.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-1_e0737ee8f71e526ad3f67d61921f2626.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-2_7651808424141b05c4860a3275a53aa4.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-2_7651808424141b05c4860a3275a53aa4.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-2_7651808424141b05c4860a3275a53aa4.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-3_6790c8b002ef5d3d8381f2308a056b1c.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-3_6790c8b002ef5d3d8381f2308a056b1c.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-3_6790c8b002ef5d3d8381f2308a056b1c.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-4_622ca1a73af549a74c4b1f11f2864582.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-4_622ca1a73af549a74c4b1f11f2864582.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-4_622ca1a73af549a74c4b1f11f2864582.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-5_58dee7259c746dcb42459118e9f3fa17.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-5_58dee7259c746dcb42459118e9f3fa17.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-5_58dee7259c746dcb42459118e9f3fa17.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-6_e0c105c8114dbd1e87bf8bf238d10a76.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-6_e0c105c8114dbd1e87bf8bf238d10a76.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-6_e0c105c8114dbd1e87bf8bf238d10a76.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-7_706a6cc70a5d784b8d55d9abd8c7c1ff.RData
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-7_706a6cc70a5d784b8d55d9abd8c7c1ff.rdb
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_cache/html/unnamed-chunk-7_706a6cc70a5d784b8d55d9abd8c7c1ff.rdx
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_files/figure-html/unnamed-chunk-3-1.png
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_files/figure-html/unnamed-chunk-4-1.png
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_files/figure-html/unnamed-chunk-5-1.png
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_files/figure-html/unnamed-chunk-6-1.png
#  create mode 100644 notebooks/8-15  -  first drafts/EDA_-_first_draft_files/figure-html/unnamed-chunk-7-1.png
#  create mode 100644 notebooks/8-15  -  first drafts/Weekly_data_tokenized.csv
#  create mode 100644 notebooks/8-15  -  first drafts/Weekly_data_tokenized_unique.csv
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/01 - Scraping data-checkpoint.ipynb (92%)
#  rewrite notebooks/weekly top 100/01 - Scraping data.ipynb (88%)
#  create mode 100644 notebooks/weekly top 100/Weekly_ranks.csv
#
#
#
#
#
# [master a71273f] first draft
#  5 files changed, 2220 insertions(+), 182 deletions(-)
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/autopusher-checkpoint.ipynb (60%)
