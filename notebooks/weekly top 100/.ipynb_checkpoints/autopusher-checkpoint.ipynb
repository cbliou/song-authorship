# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "'autoupdate'"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(600, 20) * 2)
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master 8ac2051] 'autoupdate'
#  2 files changed, 158 insertions(+)
#  create mode 100644 notebooks/weekly top 100/.ipynb_checkpoints/autopusher-checkpoint.ipynb
#  create mode 100644 notebooks/weekly top 100/autopusher.ipynb
#
#
#
#
#
# [master 28f646a] 'autoupdate'
#  4 files changed, 1678 insertions(+), 270 deletions(-)
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/autopusher-checkpoint.ipynb (60%)
#  rewrite notebooks/weekly top 100/autopusher.ipynb (60%)
#
#
#
#
#
# [master f247bc3] 'autoupdate'
#  3 files changed, 5333 insertions(+), 424 deletions(-)
#
#
#
#
#
# [master 07b598b] 'autoupdate'
#  4 files changed, 15890 insertions(+), 7008 deletions(-)
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/01 - Scraping data-checkpoint.ipynb (92%)
#  rewrite notebooks/weekly top 100/01 - Scraping data.ipynb (92%)
#
#
#
#
#
# [master f1c400a] 'autoupdate'
#  5 files changed, 20916 insertions(+), 15867 deletions(-)
#  create mode 100644 data/Weekly_ranks.csv
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/01 - Scraping data-checkpoint.ipynb (93%)
#  rewrite notebooks/weekly top 100/01 - Scraping data.ipynb (93%)
