# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
#path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"
path = "C:\\Users\\Sam\\Desktop\\song authorship"\

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "autoupdate"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(600, 20) * 2)
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master b205981] autoupdate
#  4 files changed, 44 insertions(+), 22 deletions(-)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-3-c6ccccb0caa8> in <module>()
#       6     print(x)
#       7     time.sleep(np.random.normal(5, 1) * 2)
# ----> 8     x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
#       9     print(x)
#      10     time.sleep(np.random.normal(600, 20) * 2)
#
# C:\Users\Sam\Anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# C:\Users\Sam\Anaconda3\lib\subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     416         if check and retcode:
#     417             raise CalledProcessError(retcode, process.args,
# --> 418                                      output=stdout, stderr=stderr)
#     419     return CompletedProcess(process.args, retcode, stdout, stderr)
#     420
#
# CalledProcessError: Command '['git', 'push']' returned non-zero exit status 128.
