# %% [markdown]
# # EDA
# #### Charlie Liou
#
# Let's first use the word "Robotic" to refer to songs where an external songwriter was credited.
# In this notebook, we do several exploratory analyses:
#
# - Log-odds ratio of words in robotic songs and words in non-robotic songs
# - Sentiment analysis between robotic and non-robotic songs
# - Latent Dirichlet Allocation, unsupervised
# - Word2Vec (when I figure out how to use Rtools with 3.5.1)
#  - meanwhile, got a Python analysis going

# %%
# install.packages("magrittr")
# install.packages("tidytext")
# install.packages("ggplot2")
# install.packages("tm")
# install.packages("topicmodels")
# install.packages("broom")
# install.packages("devtools")
# devtools::install_github("bmschmidt/wordVectors") 
# Rtools not compatible w/ 3.5.1, MAJOR RIP

library(purrr)
library(magrittr)
library(tidyr)
library(tidytext)
library(dplyr)
library(stringr)
library(ggplot2)
library(tm)
library(topicmodels)
library(broom)
# Out:
# Attaching package: 'magrittr'
#
# The following object is masked from 'package:purrr':
#
#     set_names
#
#
# Attaching package: 'tidyr'
#
# The following object is masked from 'package:magrittr':
#
#     extract
#
#
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Loading required package: NLP
#
# Attaching package: 'NLP'
#
# The following object is masked from 'package:ggplot2':
#
#     annotate

# %%
library = "C:\\Users\\liblabs-user\\Desktop\\song-authorship\\data"
laptop = "not yet"
desktop = "C:\\Users\\Sam\\Desktop\\song authorship\\data"

# %%
df <- read.csv(
    paste(desktop, "\\Weekly_data_clean.csv", sep = ""),
    encoding = "UTF-8",
    stringsAsFactors = FALSE)

# %%
reg <- "([^A-Za-z\\d#@']+|'[^A-Za-z\\d#@]+)"

df_words <- df %>%
    unnest_tokens(word, Lyrics, token = "regex", pattern = reg, collapse = TRUE) %>%
    filter(!word %in% stop_words$word, 
           str_detect(word, "[a-z]"))

# %% [markdown]
# # Analysis on all data

# %%
num_words_to_filter = 50

# %% [markdown]
# ## Log-odds ratio

# %%
unique_df_words <- unique(df_words)

ratios <- unique_df_words %>%
    count(word, Songwriter) %>%
    filter(n > num_words_to_filter) %>%
    spread(Songwriter, n, fill = 0) %>%
    ungroup() %>% #what is this used for?
    mutate_each(funs((. + 1) / sum(. + 1)), -word) %>%
    mutate(logratio = log2(True / False)) %>%
    arrange(desc(logratio)) #%>%
# Out:
# `mutate_each()` is deprecated.
# Use `mutate_all()`, `mutate_at()` or `mutate_if()` instead.
# To map `funs` over a selection of variables, use `mutate_at()`

# %%
rbind(ratios %>% top_n(30, logratio), ratios %>% top_n(-30, logratio)) %>%
    mutate(word = reorder(word, logratio)) %>%
    ggplot(aes(word, logratio)) +
    geom_col(show.legend = FALSE) +
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# ## Sentiment Analysis

# %%
nrc <- sentiments %>%
    filter(lexicon == "nrc") %>%
    dplyr::select(word, sentiment)

sources <- df_words %>%
    group_by(Songwriter) %>%
    mutate(total_words = n()) %>%
    ungroup() %>%
    distinct(Name, Songwriter, total_words)

by_source_sentiment <- df_words %>%
    inner_join(nrc, by = "word") %>%
    count(sentiment, Name) %>%
    ungroup() %>%
    complete(sentiment, Name, fill = list(n = 0)) %>%
    inner_join(sources, "Name") %>%
    group_by(Songwriter, sentiment, total_words) %>%
    summarize(words = sum(n)) %>%
    ungroup()

sentiment_diff <- by_source_sentiment %>%
    group_by(sentiment) %>%
    do(tidy(poisson.test(.$words, .$total_words))) %>%
    ungroup()

# %%
sentiment_diff %>%
    mutate(sentiment = reorder(sentiment, estimate)) %>%
    ggplot(aes(sentiment, estimate)) + 
    geom_errorbar(width = .5, aes(ymin = conf.low, ymax = conf.high)) +
    geom_point(shape = 21, size = 2.5, fill = "white") +
    scale_y_continuous("% change in Robotic relative to non-Robotic",
                       breaks = c(0.6, 0.8, 1, 1.2, 1.4, 1.6),
                       labels = c("-40%", "-20%", "0%", "20%", "40%", "60%")) +
    coord_flip()
# Out:
# plot without title

# %%
ratios <- unique_df_words %>%
    count(word, Songwriter) %>%
    filter(n > num_words_to_filter) %>%
    spread(Songwriter, n, fill = 0) %>%
    ungroup() %>% #what is this used for?
    mutate_each(funs((. + 1) / sum(. + 1)), -word) %>%
    mutate(logratio = log2(True / False)) %>%
    arrange(desc(logratio))

ratios %>%
    inner_join(nrc, by = "word") %>%
    filter(!sentiment %in% c("positive", "negative")) %>%
    mutate(sentiment = reorder(sentiment, -logratio),
           word = reorder(word, -logratio)) %>%
    group_by(sentiment) %>%
    top_n(10, abs(logratio)) %>%
    ungroup() %>%
    ggplot(aes(word, logratio, fill = logratio < 0)) +
    facet_wrap(~ sentiment, scales = "free", nrow = 2) +
    geom_bar(stat = "identity") +
    theme(axis.text.x = element_text(angle = 90, hjust = 1)) +
    labs(x = "", y = "Robotic / non-Robotic log ratio") +
    scale_fill_manual(name = "", labels = c("Robotic", "non-Robotic"),
                    values = c("#E69F00", "#56B4E9"))
# Out:
# `mutate_each()` is deprecated.
# Use `mutate_all()`, `mutate_at()` or `mutate_if()` instead.
# To map `funs` over a selection of variables, use `mutate_at()`
# plot without title

# %% [markdown]
# ## Latent Dirichlet Allocation

# %%
word_counts <- df_words %>%
    count(Name, word, sort = TRUE) %>%
    filter(n > num_words_to_filter) %>%
    ungroup() # do we need this?
    
word_count_matrix <- word_counts %>% cast_dtm(Name, word, n)
# Out:
# Warning message:
# "Trying to compute distinct() for variables not found in the data:
# - `row_col`, `column_col`
# This is an error, but only a warning is raised for compatibility reasons.
# The operation will return the input unchanged."

# %% [markdown]
# We start with two topics. For both topics, let us first observe the most probable terms that will be generated from each topic (terms with high $\beta$).

# %%
# create LDA object
songs_lda <- LDA(word_count_matrix, k = 2, control = list(seed = 0))
topics <- tidy(songs_lda, matrix = "beta")
    
# visualize
top_terms <- topics %>%
    group_by(topic) %>%
    top_n(40, beta) %>%
    ungroup() %>%
    arrange(topic, -beta)
    
top_terms %>%
    mutate(term = reorder(term, beta)) %>%
    ggplot(aes(term, beta, fill = factor(topic))) +
    geom_col(show.legend = FALSE) +
    facet_wrap(~ topic, scales = "free") + # partition by topic
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# We now consider words that had the greatest difference in $\beta$.

# %%
beta_spread <- topics %>%
    mutate(topic = paste0("topic", topic)) %>% # adds topic to each number
    spread(topic, beta) %>% # key, values w/ values for each var
    filter(topic1 > .005 | topic2 > .005) %>%
    mutate(log_ratio = log2(topic2 / topic1)) %>%
    #filter(abs(log_ratio) < 50) %>%
    arrange(-log_ratio)

# plot
beta_spread %>%
    mutate(term = reorder(term, log_ratio)) %>%
    ggplot(aes(term, log_ratio)) + 
    geom_col(show.legend = FALSE) +
    coord_flip()
# Out:
# plot without title

# %% [markdown]
# In this case, topic 2 is definitely more of a hip-hop / rap topic.

# %% [markdown]
# ## By genre: Pop

# %%
popdf <- df_words %>% 
         filter("Pop" %in% Genre, 
           str_detect(Genre, "[a-z]"))

# %%
head(popdf, 20)
# Out:
#    Artists  Name      Peak.position Week       Weekly.rank Weeks.on.chart
# 1  2 Chainz Watch Out 64            2016-02-12 64          5
# 2  2 Chainz Watch Out 64            2016-02-12 64          5
# 3  2 Chainz Watch Out 64            2016-02-12 64          5
# 4  2 Chainz Watch Out 64            2016-02-12 64          5
# 5  2 Chainz Watch Out 64            2016-02-12 64          5
# 6  2 Chainz Watch Out 64            2016-02-12 64          5
# 7  2 Chainz Watch Out 64            2016-02-12 64          5
# 8  2 Chainz Watch Out 64            2016-02-12 64          5
# 9  2 Chainz Watch Out 64            2016-02-12 64          5
# 10 2 Chainz Watch Out 64            2016-02-12 64          5
# 11 2 Chainz Watch Out 64            2016-02-12 64          5
# 12 2 Chainz Watch Out 64            2016-02-12 64          5
# 13 2 Chainz Watch Out 64            2016-02-12 64          5
# 14 2 Chainz Watch Out 64            2016-02-12 64          5
# 15 2 Chainz Watch Out 64            2016-02-12 64          5
# 16 2 Chainz Watch Out 64            2016-02-12 64          5
# 17 2 Chainz Watch Out 64            2016-02-12 64          5
# 18 2 Chainz Watch Out 64            2016-02-12 64          5
# 19 2 Chainz Watch Out 64            2016-02-12 64          5
# 20 2 Chainz Watch Out 64            2016-02-12 64          5
#    Date            Genre        Writing.Credits                  Songwriter
# 1  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 2  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 3  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 4  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 5  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 6  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 7  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 8  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 9  August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 10 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 11 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 12 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 13 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 14 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 15 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 16 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 17 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 18 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 19 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
# 20 August 13, 2015 Atlanta, Rap Saucelordrich, Fki 1st, 2 chainz False
#    word
# 1  watch
# 2  yo
# 3  niggas
# 4  niggas
# 5  niggas
# 6  ballin
# 7  niggas
# 8  athletic
# 9  niggas
# 10 a1
# 11 street
# 12 cred
# 13 niggas
# 14 ballin
# 15 niggas
# 16 athletic
# 17 pulled
# 18 phantom
# 19 pulled
# 20 dancer
