# %%
import re
import pandas as pd
import numpy as np
import csv
import json
import os

# %%
library = "C:\\Users\\liblabs-user\\Desktop\\song-authorship\\data"
laptop = "not yet"
desktop = "C:\\Users\\Sam\\Desktop\\song authorship\\data"

# %%
pd.read_csv(open(desktop + "\\Weekly_data.csv")).head()
# Out:
#                                           Artists            Name  \
# 0                                           Drake  In My Feelings
# 1                   6ix9ineNicki MinajMurda Beatz            FEFE
# 2                                 Maroon 5Cardi B  Girls Like You
# 3  DJ KhaledJustin Bieber, Chance The RapperQuavo      No Brainer
# 4                                     Post Malone      Better Now
#
#    Peak position        Week  Weekly rank  Weeks on chart            Date  \
# 0            1.0  2018-08-11            1             5.0   June 29, 2018
# 1            3.0  2018-08-11            3             2.0   July 22, 2018
# 2            3.0  2018-08-11            4            10.0    May 30, 2018
# 3            NaN  2018-08-11            5             NaN   July 27, 2018
# 4            5.0  2018-08-11            6            14.0  April 27, 2018
#
#                                                Genre  \
# 0  Quality Control Music, Florida, Republic Recor...
# 1  Universal, YMCMB, Republic Records, Trap, New ...
# 2  New York, Warner Bros., Atlantic Records, Inte...
# 3  Capitol Records, Motown, Universal, R&B, Elect...
# 4  R&B, Republic Records, Pop, Trap, New York, Cl...
#
#                                      Writing Credits  \
# 0  Phillip price, Orville hall, Magnolia shorty, ...
# 1  Baka, Cubeatz, Tr3yway ceo, Nicki minaj, Murda...
# 2  Cardi b, Gian michael stone, Starrah, Adam lev...
# 3  Dj khaled, Justin bieber, Quavo, Chance the ra...
# 4  Billy walsh, Frank dukes, Louis bell, Post malone
#
#                                               Lyrics  Songwriter
# 0  In My Feelings \nTrap, TrapMoneyBenny\nThis sh...       False
# 1  FEFE \nIt's fuckin' TR3YWAY!\nKing of New York...       False
# 2  Girls Like You Remix \nSpent 24 hours, I need ...        True
# 3  No Brainer \nWe the Best Music!\nAnother one!\...       False
# 4  Better Now \nYou prolly think that you are bet...       False

# %%
os.chdir(desktop)
df = pd.read_csv(open(desktop + "\\Weekly_data.csv"))

# %%
def isnull(x):
    """
    """
    return x != x

# %%
def clean_lyric(lyric):
    
    repl = {"\[.+?\]": "", "\s{2,}": "\n", "lyrics": "", "\(": "", "\)": ""}
    
    for i in repl:
        lyric = re.sub(i, repl[i], lyric, flags = re.I | re.S)
    
    return lyric

# %%
filler = [" and ", " featuring ", " & ", " x ", " / "]
repl = {"(\"|”).+?(\"|”)": "", "\s+": " ", "\s,": ","}
textcols = ["Artists", "Name", "Genre", "Writing Credits", "Lyrics"]
#textcols = ["Genre"]
for i in textcols:
    for j in range(len(df)):
        if not isnull(df.loc[j, i]):
            if i == "Artists":
                for k in filler:
                    df.loc[j, i] = re.sub(k, ",", df.loc[j, i], flags = re.I | re.S)
            elif i == "Lyrics":
                df.loc[j, i] = clean_lyric(df.loc[j, i])
            else:
                for k in repl:
                    df.loc[j, i] = re.sub(k, repl[k], df.loc[j, i], flags = re.I | re.S)
                df.loc[j, i] = df.loc[j, i].strip()

# %% [markdown]
# ## Add songwriters

# %%
writers = json.load(open(desktop + "\\composers.json", "r"))
writers[1] = "Tobias Jesso Jr"
writers[5] = "Jacob Kasher"
writers[10] = "Pop and Oak"
writers[16] = "Mike Will Made It"
del writers[9]
writers.append("Justin Tranter")
writers.append("Julia Michaels")

# %% [markdown]
# We add Rex Zamor to the list as well:
#  - https://www.allmusic.com/artist/rex-zamor-mn0002136805

# %%
writers.append("Rex Zamor")

# %% [markdown]
# We add Jim Jonson:
# - https://en.wikipedia.org/wiki/Jim_Jonsin

# %%
writers.append("Jim Jonsin")

# %% [markdown]
# - https://en.wikipedia.org/wiki/Alan_and_Marilyn_Bergman

# %%
writers.append("Alan Bergman")
writers.append("Marilyn Bergman")

# %% [markdown]
# - https://en.wikipedia.org/wiki/Jason_Evigan

# %%
writers.append("Jason Evigan")

# %%
df.head()
# Out:
#                                           Artists            Name  \
# 0                                           Drake  In My Feelings
# 1                   6ix9ineNicki MinajMurda Beatz            FEFE
# 2                                 Maroon 5Cardi B  Girls Like You
# 3  DJ KhaledJustin Bieber, Chance The RapperQuavo      No Brainer
# 4                                     Post Malone      Better Now
#
#    Peak position        Week  Weekly rank  Weeks on chart            Date  \
# 0            1.0  2018-08-11            1             5.0   June 29, 2018
# 1            3.0  2018-08-11            3             2.0   July 22, 2018
# 2            3.0  2018-08-11            4            10.0    May 30, 2018
# 3            NaN  2018-08-11            5             NaN   July 27, 2018
# 4            5.0  2018-08-11            6            14.0  April 27, 2018
#
#                                                Genre  \
# 0  Quality Control Music, Florida, Republic Recor...
# 1  Universal, YMCMB, Republic Records, Trap, New ...
# 2  New York, Warner Bros., Atlantic Records, Inte...
# 3  Capitol Records, Motown, Universal, R&B, Elect...
# 4  R&B, Republic Records, Pop, Trap, New York, Cl...
#
#                                      Writing Credits  \
# 0  Phillip price, Orville hall, Magnolia shorty, ...
# 1  Baka, Cubeatz, Tr3yway ceo, Nicki minaj, Murda...
# 2  Cardi b, Gian michael stone, Starrah, Adam lev...
# 3  Dj khaled, Justin bieber, Quavo, Chance the ra...
# 4  Billy walsh, Frank dukes, Louis bell, Post malone
#
#                                               Lyrics  Songwriter
# 0  In My Feelings\nTrap, TrapMoneyBenny\nThis shi...       False
# 1  FEFE\nIt's fuckin' TR3YWAY!\nKing of New York,...       False
# 2  Girls Like You Remix\nSpent 24 hours, I need m...        True
# 3  No Brainer\nWe the Best Music!\nAnother one!\n...       False
# 4  Better Now\nYou prolly think that you are bett...       False

# %%
composers = []
for i in range(len(df)):
    for j in writers:
        if not isnull(df.loc[i, "Writing Credits"]):
            if re.search(j, df.loc[i, "Writing Credits"], flags = re.I | re.S) is not None:
                if re.search(df)
                composers.append(True)
                break
    else:
        composers.append(False)

# %%
df["Songwriter"] = np.array(composers)

# we drop NA's here for convenience now....will fix later
df = df[df.Lyrics == df.Lyrics]
df.to_csv("Weekly_data_clean.csv", index = False)
