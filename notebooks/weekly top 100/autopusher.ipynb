# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
#path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"
path = "C:\\Users\\Sam\\Desktop\\song authorship"\

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "autoupdate"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(600, 20) * 2)
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master 6cd76ec] 'autoupdate'
#  10 files changed, 157 insertions(+), 23 deletions(-)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/.ipynb_checkpoints/01 - Scraping Data-checkpoint.ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/01 - Scraping Data.ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/02 - Cleaning Data.ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/03 - EDA (Python).ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/03 - EDA (R).ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/03 - EDA (old) (python).ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/Untitled.ipynb (100%)
#  rename notebooks/{2017 top 100 only => prototyping on 2017 yearly top 100}/get songwriters.ipynb (100%)
