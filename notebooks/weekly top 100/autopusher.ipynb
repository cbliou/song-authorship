# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
#path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"
path = "C:\\Users\\Sam\\Desktop\\song authorship"\

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "data pipeline in progress"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(600, 20) * 2)
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master a2bcb87] data pipeline in progress
#  4 files changed, 143 insertions(+), 68 deletions(-)
#
#
#
#
#
# [master 793fc69] data pipeline in progress
#  4 files changed, 112 insertions(+), 148 deletions(-)
#
#
#
#
#
# [master 7d3fc23] data pipeline in progress
#  2 files changed, 1475 insertions(+)
#
#
#
#
#
# [master 441650a] data pipeline in progress
#  2 files changed, 1534 insertions(+), 1 deletion(-)
#
#
#
#
#
# [master 451de04] data pipeline in progress
#  2 files changed, 2325 insertions(+), 1 deletion(-)
#
#
#
#
#
# [master d9ac67f] data pipeline in progress
#  2 files changed, 1407 insertions(+), 1 deletion(-)
#
#
#
#
#
# [master d17c065] data pipeline in progress
#  1 file changed, 7 insertions(+)
#
#
#
#
#
# [master 801bfb0] data pipeline in progress
#  1 file changed, 7 insertions(+)
#
#
#
#
#
# [master 4bb2cf4] data pipeline in progress
#  1 file changed, 7 insertions(+)
#
#
#
#
#
# [master 5df7dce] data pipeline in progress
#  1 file changed, 7 insertions(+)
#
#
#
#
# ...
