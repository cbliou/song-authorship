# %%
from subprocess import check_output
import time
import os
import numpy as np

# %%
#path = "C:\\Users\\liblabs-user\\Desktop\\lol\\song-authorship"
path = "C:\\Users\\Sam\\Desktop\\song authorship"\

# %%
while True:
    x = check_output(["git", "add", "."], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "commit", "-m", "analysis in progress"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(5, 1) * 2)
    x = check_output(["git", "push"], shell = True, universal_newlines = True, cwd = path)
    print(x)
    time.sleep(np.random.normal(2000, 20))
    print()
    print()
    #check_output([\"del\", \"/s\", \"/q\", x], shell = True, universal_newlines = True, cwd = path)"
# Out:
# [master 847c1c7] data pipeline in progress
#  4 files changed, 143 insertions(+), 2090 deletions(-)
#
#
#
#
#
# [master 257c957] data pipeline in progress
#  8 files changed, 1574816 insertions(+), 434 deletions(-)
#  create mode 100644 data/Weekly_data.csv
#  rename {notebooks/weekly top 100 => data}/Weekly_ranks.csv (100%)
#  create mode 100644 notebooks/weekly top 100/.ipynb_checkpoints/02 - Cleaning data-checkpoint.ipynb
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/autopusher-checkpoint.ipynb (61%)
#  create mode 100644 notebooks/weekly top 100/02 - Cleaning data.ipynb
#  rewrite notebooks/weekly top 100/autopusher.ipynb (61%)
#
#
#
#
#
# [master 614a9cc] data pipeline in progress
#  6 files changed, 2747 insertions(+), 2618 deletions(-)
#  create mode 100644 notebooks/prototyping on 2017 yearly top 100/.ipynb_checkpoints/02 - Cleaning Data-checkpoint.ipynb
#  rewrite notebooks/weekly top 100/.ipynb_checkpoints/02 - Cleaning data-checkpoint.ipynb (97%)
#  rewrite notebooks/weekly top 100/02 - Cleaning data.ipynb (97%)
