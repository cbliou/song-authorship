# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import json

from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import BernoulliNB, MultinomialNB

# %%
def KL_divergence(dist1, dist2, alpha):
    
    div = 0
    
    for element in dist1.keys():
        if element not in dist2:
            div += dist1[element] * np.log(dist1[element] / alpha)
        else:
            div += dist1[element] * np.log(dist1[element] / dist2[element])
            
    return div

def hellinger_distance(dist1, dist2, n):
    
    num = 0
    
    for element in dist1.keys():
        
        if element not in dist2:
            num += ((dist1[element]) ** (1 / n) - 0) ** n
        else:
            num += ((dist1[element]) ** (1 / n) - (dist2[element]) ** (1 / n)) ** n
        
    num = (1 / np.sqrt(n)) * (num ** (1 / n))
    
    return 1 - num

def get_word_distribution(d, type_ = "train"):
    """
    if train: return word distribution given each class
    if test: return each testing example's word distribution.
    """
    
    from collections import Counter
    from itertools import chain
    
    if type_ == "train":
        ans = Counter(list(d))
        norm = sum(ans.values())
        for element in ans:
            ans[element] /= norm
            
        impute = {}#defaultdict(float)
        for i in ans:
            impute[i] = ans[i]
        return impute

    elif type_ == "test":
        
        ans = []
        for song in d.ID.unique():
            ans1 = Counter(list(d[d.ID == song].word))
            norm = sum(ans1.values())
            for element in ans1:
                ans1[element] /= norm
                
            impute = {}#defaultdict(float)
            for i in ans1:
                impute[i] = ans1[i]
            ans.append(ans1)
        return ans
    
def classify(data, dists, n = 2, alpha = 0.1, metric = "hellinger"):
    #p_genre = {"pop": popprop, "rap": rapprop}
    results = []
    for song in data:
        distance = {}
        for dist in dists:
            if metric == "hellinger":
                distance.update({dist: hellinger_distance(song, dists[dist], n)})
            elif metric == "KL":
                distance.update({dist: KL_divergence(song, dists[dist], alpha)})
                
        if metric == "hellinger":
            results.append(max(distance.items(), key = lambda x: x[1]))
        elif metric == "KL":
            results.append(min(distance.items(), key = lambda x: x[1]))
    return results

# %% [markdown]
# ## Remove words that don't help us discriminate

# %%
df = pd.read_csv("..//..//data//Weekly_data_tokenized.csv")

# %%
len(df)
# Out:
# 583658

# %%
def create_genre(row, genre):
    if re.search(genre, row["Genre"], flags = re.I) != None:
        return 1
    else:
        return 0

# %%
df["Pop"] = df.apply(lambda row: create_genre(row, "pop"), axis = 1)
df["Rap"] = df.apply(lambda row: create_genre(row, "rap"), axis = 1)

# %%
tmp = df.groupby(["word", "Pop", "Rap"]).count().unstack().unstack().fillna(0)["Unnamed: 0"]

# %%
def calculate_gini_index(vocabulary):
    index = {}
    
    for word in vocabulary.index:
        index.update({word: sum((vocabulary.loc[word] / vocabulary.loc[word].sum()) ** 2)})
        
    return index

# %%
gini = calculate_gini_index(tmp)
useless_words = [x for x in gini if gini[x] <= .27]

# %%
with open("..//..//data//gini_indexes.json", "w") as f:
    json.dump(gini, f)

# %%
df.head()
# Out:
#    Unnamed: 0              Artists         Name  Weeks.on.chart  Weekly.rank  \
# 0           1  "weird al" yankovic  Word Crimes               2           91
# 1           2  "weird al" yankovic  Word Crimes               2           91
# 2           3  "weird al" yankovic  Word Crimes               2           91
# 3           4  "weird al" yankovic  Word Crimes               2           91
# 4           5  "weird al" yankovic  Word Crimes               2           91
#
#    Peak.position        Week           Date              Genre  \
# 0             39  2014-08-08  July 15, 2014  Parody,Comedy,Pop
# 1             39  2014-08-08  July 15, 2014  Parody,Comedy,Pop
# 2             39  2014-08-08  July 15, 2014  Parody,Comedy,Pop
# 3             39  2014-08-08  July 15, 2014  Parody,Comedy,Pop
# 4             39  2014-08-08  July 15, 2014  Parody,Comedy,Pop
#
#                                      Writing.Credits  Songwriter  ID    word  \
# 0  marvin gaye, ti, robin thicke, pharrell willia...       False   1    word
# 1  marvin gaye, ti, robin thicke, pharrell willia...       False   1  crimes
# 2  marvin gaye, ti, robin thicke, pharrell willia...       False   1    shut
# 3  marvin gaye, ti, robin thicke, pharrell willia...       False   1     woo
# 4  marvin gaye, ti, robin thicke, pharrell willia...       False   1  listen
#
#    Pop  Rap
# 0    1    0
# 1    1    0
# 2    1    0
# 3    1    0
# 4    1    0

# %%
df = df[~df.word.isin(useless_words)]

# %%
len(df)
# Out:
# 579794

# %% [markdown]
# ## Create classifier

# %%
np.random.seed(1)

IDs = df.ID.unique()
np.random.shuffle(IDs)

train = df[df.ID.isin(IDs[:int(.8 * len(IDs))])]
test = df[df.ID.isin(IDs[int(.8 * len(IDs)):])]

poptrain = train[train["Pop"] == 1].word
raptrain = train[train["Rap"] == 1].word

poptest = test[test["Pop"] == 1]
raptest = test[test["Rap"] == 1]

poptraindist = get_word_distribution(poptrain)
raptraindist = get_word_distribution(raptrain)
dists = {"pop": poptraindist, "rap": raptraindist}

poptestdist = get_word_distribution(poptest, "test")
raptestdist = get_word_distribution(raptest, "test")

numpop = len(train[train.Pop == True].ID.unique())
numrap = len(train[train.Pop == False].ID.unique())
popprop = numpop / (numpop + numrap)
rapprop = 1 - popprop

# %% [markdown]
# ## KL grid search

# %%
grid = {}

for n in range(1, 1001):
    pops = [x[0] for x in classify(poptestdist, dists, alpha = n / 10e7, metric = "KL")]
    raps = [x[0] for x in classify(raptestdist, dists, alpha = n / 10e7, metric = "KL")]
    predicted = pops + raps
    true = ["pop" for _ in range(len(pops))] + ["rap" for _ in range(len(raps))]
    grid.update({n: confusion_matrix(predicted, true).ravel()})

# %%
plt.plot([i / 10e7 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %% [markdown]
# ## Hellinger grid search

# %%
grid = {}

for n in range(1, 1001):
    pops = [x[0] for x in classify(poptestdist, dists, n = n / 100, metric = "hellinger")]
    raps = [x[0] for x in classify(raptestdist, dists, n = n / 100, metric = "hellinger")]
    predicted = pops + raps
    true = ["pop" for _ in range(len(pops))] + ["rap" for _ in range(len(raps))]
    grid.update({n: confusion_matrix(predicted, true).ravel()})

# %%
plt.plot([i / 100 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
grid = {}

for n in range(1500, 2500):
    pops = [x[0] for x in classify(poptestdist, dists, n / 1000, metric = "hellinger")]
    raps = [x[0] for x in classify(raptestdist, dists, n / 1000, metric = "hellinger")]
    predicted = pops + raps
    true = ["pop" for _ in range(len(pops))] + ["rap" for _ in range(len(raps))]
    grid.update({n: confusion_matrix(predicted, true).ravel()})

# %%
plt.plot([i / 1000 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
pops = [x[0] for x in classify(poptestdist, dists, n = 2, metric = "hellinger")]
raps = [x[0] for x in classify(raptestdist, dists, n = 2, metric = "hellinger")]
predicted = pops + raps
true = ["pop" for _ in range(len(pops))] + ["rap" for _ in range(len(raps))]
tn, fp, fn, tp = confusion_matrix(predicted, true).ravel()

# %%
confusion_matrix(predicted, true)
# Out:
# array([[319, 166],
#        [ 51, 242]], dtype=int64)

# %% [markdown]
# ### Pop class percentage

# %%
len(pops) / (len(pops) + len(raps))
# Out:
# 0.4755784061696658

# %% [markdown]
# 1. Do a write-up
# 2. Account for multiple genres within a song
# 3. dimension reduction
#
#
#
# - Account for multiple genres
# - Narrow down the dimensions
#  - reduce on the most important words
#    - gini coefficient
#  - reduce w/ linear algebra technique
#    - LDA
# - try different metrics
#  - KL divergence
# - don't want to lean on infrequent words too much

# %% [markdown]
# Naive bayes accuracy is NOT 57.21%. Let Bodwin know what you did wrong.

# %% [markdown]
# ### Accuracy

# %%
(tn + tp) / (tn + fp + fn + tp)
# Out:
# 0.7210796915167095

# %% [markdown]
# ### Precision

# %%
tp / (tp + fp)
# Out:
# 0.5931372549019608

# %% [markdown]
# ### Recall

# %%
tp / (tp + fn)
# Out:
# 0.825938566552901

# %% [markdown]
# # Naive Bayes comparison

# %%
def build_vocabulary(df, vocab = {}):
    """
    df: dataframe of tidy data to build vocab
    """
    index = len(vocab)

    for document in df.ID.unique():
        words = df[df.ID == document].word
        for word in words:
            if word not in vocab:
                vocab.update({word: index})
                index += 1
    return vocab


def build_word_vector(vocab, document):
    """
    vocab: dictionary with key = word, value = index of list to populate
    document: document to build a word vector from
    returns: a word vector with 0 = word not present, 1 = word present
    """
    vec = np.zeros(len(vocab))
    words = document.word
    for word in words:
        if word in vocab:
            vec[vocab[word]] += 1
    return vec

# %%
train_words = train[["ID", "Pop", "word"]]
test_words = test[["ID", "Pop", "word"]]

vocab = build_vocabulary(train_words)
vocab = build_vocabulary(test_words, vocab)

# %%
X_train, y_train, X_test, y_test = [], [], [], []

for doc in train_words.ID.unique():
    tmp = train_words[train_words.ID == doc]
    X_train.append(build_word_vector(vocab, tmp))
    y_train.append(tmp.Pop.iloc[0])
    
for doc in test_words.ID.unique():
    tmp = test_words[test_words.ID == doc]
    X_test.append(build_word_vector(vocab, tmp))
    y_test.append(tmp.Pop.iloc[0])

# %%
grid = {}

for n in range(1, 501):
    clf = BernoulliNB(alpha = n / 100)
    clf.fit(X_train, y_train)
    grid.update({n: confusion_matrix(clf.predict(X_test), y_test).ravel()})

# %%
plt.plot([i / 100 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
grid = {}

for n in range(1, 101):
    clf = BernoulliNB(alpha = n / 1000)
    clf.fit(X_train, y_train)
    grid.update({n: confusion_matrix(clf.predict(X_test), y_test).ravel()})

# %%
plt.plot([i / 100 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
clf = BernoulliNB(alpha = 1)
clf.fit(X_train, y_train)
# Out:
# BernoulliNB(alpha=1, binarize=0.0, class_prior=None, fit_prior=True)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_test), y_test).ravel()

# %%
confusion_matrix(clf.predict(X_test), y_test)
# Out:
# array([[213,  39],
#        [195, 331]], dtype=int64)

# %%
(tn + tp) / (tn + fp + fn + tp)
# Out:
# 0.699228791773779

# %%
tp / (tp + fp)
# Out:
# 0.8945945945945946

# %%
tp / (tp + fn)
# Out:
# 0.629277566539924

# %%
grid = {}

for n in range(1, 101):
    clf = MultinomialNB(alpha = n / 1000)
    clf.fit(X_train, y_train)
    grid.update({n: confusion_matrix(clf.predict(X_test), y_test).ravel()})

# %%
plt.plot([i / 100 for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
clf = MultinomialNB(alpha = 1)
clf.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1, class_prior=None, fit_prior=True)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_test), y_test).ravel()

# %%
confusion_matrix(clf.predict(X_test), y_test)
# Out:
# array([[267,  70],
#        [141, 300]], dtype=int64)

# %%
(tn + tp) / (tn + fp + fn + tp)
# Out:
# 0.7287917737789203

# %%
tp / (tp + fp)
# Out:
# 0.8108108108108109

# %%
tp / (tp + fn)
# Out:
# 0.6802721088435374
