# %% [markdown]
# ## Predictive Modeling - Neural network

# %%
import re
import numpy as np
import pandas as pd
import json
import sys
from collections import Counter
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from keras import layers
from keras.models import Sequential, load_model
from keras.preprocessing.sequence import pad_sequences
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
library = "C:\\Users\\liblabs-user\\Desktop\\song-authorship\\data"
laptop = "not yet"
desktop = "C:\\Users\\Sam\\Desktop\\song authorship\\data"

# %% [markdown]
# Since lyrics do not have sentences, we will delimit the sentences using the new line character.

# %%
re.sub("in'{1} ", "ing ", "in'")
# Out:
# "in'"

# %%
def clean_text(text, names, unicode_replace):
    remove = ["_", "*", "--", ",", "!", "?", " < ", " > ", ":"]
    repl = {"\<u\+0092\>": "'",
            "\<u\+0097\>": "-",
            "\<u\+00..\>": "",
            " '{0,}": " ",
            "in'{0,} ": "ing ",
            "\.{0,} ": " ",
            " \.{0,}": " ",
            ' "{0,}': " ",
            '"{0,} ': " ",
            }
    text = text.lower()
    for x in remove:
        text = text.replace(x, "")
    for x in repl:
        text = re.sub(x, repl[x], text, flags = re.I | re.S)
    for x in unicode_replace:
        text = re.sub(x, "", text, flags = re.I | re.S)    
    return [x.strip() for x in re.split("\n", text) if x.strip() != ""]

def data_generator(robot, nonrobot, s_min, s_max, a_min, a_max,
                   lookback, batch_size=128):

    if s_max is None:
        s_max = len(robot)
    if a_max is None:
        a_max = len(nonrobot)

    si = s_min
    ai = a_min

    while 1:

        follow = np.random.randint(0, 2, batch_size)
        sind = []
        aind = []

        for x in follow:
            # robotic is 0
            if x == 0:
                if si >= s_max:
                    si = s_min
                sind.append(si)
                aind.append(-1)
                si += 1
            else:
                if ai >= a_max:
                    ai = a_min
                aind.append(ai)
                sind.append(-1)
                ai += 1

        samples = []

        # now pad sentences and yield.
        for x in range(len(sind)):
            # sampled non-robotic here
            if sind[x] == -1:
                samples.append(nonrobot[aind[x]])
            else:
                samples.append(robot[sind[x]])

        yield np.array(samples), follow
        
def combine_phrases(n, song):
    """
    n: Number of phrases to combine together
    song: list of phrases to combine
    
    returns: list of combined sentences.
    """
    
    if len(song) <= n:
        return [" ".join(song)]
    else:
        add = []
        itor = list(range(0, len(song) - n, n))
        for i in itor:
            add.append(" ".join(song[i: i + n]))
        
        add.append(" ".join(song[itor[-1] + n:]))

        return add
    
def prepare_data(sentence, stopwords):
    sentence = word_tokenize(sentence)
    #sentence = [i for i in sentence if i not in stopwords]
    return sentence

# %%
split = 0.8
number_of_words = 5000
num_combine = 3
np.random.seed(0)

# %%
df = pd.read_csv(desktop + "\\Weekly_data_top_week.csv")
names = "\s"
unicode_replace  = json.load(open(desktop + "\\unicoderemove.json", "r"))
stopwords = set(stopwords.words('english'))

robotic = [clean_text(x, names, unicode_replace) 
           for x in df[df.Songwriter == True].Lyrics]
nonrobotic = [clean_text(x, names, unicode_replace) 
              for x in df[df.Songwriter == False].Lyrics]

robotic = [combine_phrases(num_combine, i) for i in robotic]
nonrobotic = [combine_phrases(num_combine, i) for i in nonrobotic]

# test train split
rt = np.random.choice(len(robotic),
                      round(len(robotic) * split),
                      replace=False)
rtrain = [prepare_data(y, stopwords) for x in rt for y in robotic[x]]
rtest = [prepare_data(y, stopwords) for x in set(range(len(robotic))).difference(rt) for y in robotic[x]]

nt = np.random.choice(len(nonrobotic),
                      round(len(nonrobotic) * split),
                      replace=False)
ntrain = [prepare_data(y, stopwords) for x in nt for y in nonrobotic[x]]
ntest = [prepare_data(y, stopwords) for x in set(range(len(nonrobotic))).difference(nt) for y in nonrobotic[x]]

# vectorize sentences
tokenizer = Tokenizer(num_words=number_of_words,
                      filters="'!\"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'",
                      lower=True, split=' ')
tokenizer.fit_on_texts(rtrain)
tokenizer.fit_on_texts(ntrain)
tokenizer.fit_on_texts(rtest)
tokenizer.fit_on_texts(ntest)

rtrain = pad_sequences(tokenizer.texts_to_sequences(rtrain), 30)
#print()
#print(rtrain[0:10])
rtest = pad_sequences(tokenizer.texts_to_sequences(rtest), 30)
ntrain = pad_sequences(tokenizer.texts_to_sequences(ntrain), 30)
ntest = pad_sequences(tokenizer.texts_to_sequences(ntest), 30)

# %%
max(tokenizer.word_index.values())
# Out:
# 29276

# %%
lookback = 30
batch_size = 8

#stoker = pad_sequences(np.array(json.load(open(sys.argv[1].strip()))), 60)
#austen = pad_sequences(np.array(json.load(open(sys.argv[2].strip()))), 60)

#stoker_train = stoker[:round(len(stoker) * 0.9)]
#stoker_val = stoker[round(len(stoker) * 0.9):]

#austen_train = austen[:round(len(austen) * 0.9)]
#austen_val = austen[round(len(austen) * 0.9):]

train_gen = data_generator(robot=rtrain,
                           nonrobot=ntrain,
                           s_min=0,
                           s_max=len(rtrain),
                           a_min=0,
                           a_max=len(ntrain),
                           lookback=lookback,
                           batch_size=batch_size)

val_gen = data_generator(robot=rtest,
                         nonrobot=ntest,
                         s_min=0,
                         s_max=len(rtest),
                         a_min=0,
                         a_max=len(ntest),
                         lookback=lookback,
                         batch_size=batch_size)

model = Sequential()
model.add(layers.Embedding(number_of_words, 64))
model.add(layers.Bidirectional(
            layers.LSTM(16,
            activation="relu",
            dropout=0.2,
            recurrent_dropout=0.2,
            return_sequences=True)))
model.add(layers.Bidirectional(
            layers.LSTM(8,
            activation="relu",
            recurrent_dropout=0.2,
            return_sequences=True)))
model.add(layers.GlobalMaxPool1D())

model.add(layers.Dense(1, activation="sigmoid"))

model.compile(optimizer=RMSprop(),
              loss="binary_crossentropy",
                metrics=["acc"])

filepath = "weights-improvement-{epoch:02d}-{val_acc:.4f}.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc',
                             verbose=1, save_best_only=True,
                             mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(train_gen,
                              steps_per_epoch=200,
                              epochs=20,
                              callbacks=callbacks_list,
                              validation_data=val_gen,
                              validation_steps=200)

#with open("Embedding.dat", "w") as f:
#    porv = load_model("RoboticorNot.h5")
#    json.dump(list([list(x) for x in
#                    porv.layers[0].get_weights()[0].astype(float)]), f)
# Out:
# Epoch 1/20
# 200/200 [==============================] - 11s 56ms/step - loss: 0.6859 - acc: 0.5525 - val_loss: 0.7080 - val_acc: 0.4956
#
# Epoch 00001: val_acc improved from -inf to 0.49562, saving model to weights-improvement-01-0.4956.h5
# Epoch 2/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.6818 - acc: 0.5637 - val_loss: 0.7049 - val_acc: 0.4750s - loss:
#
# Epoch 00002: val_acc did not improve
# Epoch 3/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7697 - acc: 0.6212 - val_loss: 0.7055 - val_acc: 0.5513
#
# Epoch 00003: val_acc improved from 0.49562 to 0.55125, saving model to weights-improvement-03-0.5513.h5
# Epoch 4/20
# 200/200 [==============================] - 8s 39ms/step - loss: 0.7825 - acc: 0.6375 - val_loss: 0.7073 - val_acc: 0.5569
#
# Epoch 00004: val_acc improved from 0.55125 to 0.55688, saving model to weights-improvement-04-0.5569.h5
# Epoch 5/20
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6681 - acc: 0.6675 - val_loss: 0.8211 - val_acc: 0.5075
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 200/200 [==============================] - 9s 44ms/step - loss: 0.7343 - acc: 0.5950 - val_loss: 0.7021 - val_acc: 0.5025
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6900 - acc: 0.6162 - val_loss: 0.6767 - val_acc: 0.5550
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7210 - acc: 0.6250 - val_loss: 0.7301 - val_acc: 0.4888
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.6630 - acc: 0.6019 - val_loss: 0.7342 - val_acc: 0.6000
#
# Epoch 00009: val_acc improved from 0.55688 to 0.60000, saving model to weights-improvement-09-0.6000.h5
# Epoch 10/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7882 - acc: 0.6244 - val_loss: 0.7444 - val_acc: 0.5188
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7401 - acc: 0.6181 - val_loss: 0.6914 - val_acc: 0.5463
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6971 - acc: 0.6387 - val_loss: 0.9476 - val_acc: 0.4888
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 200/200 [==============================] - 8s 42ms/step - loss: 0.6544 - acc: 0.6750 - val_loss: 0.8332 - val_acc: 0.5406
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 200/200 [==============================] - 8s 41ms/step - loss: 0.6649 - acc: 0.6587 - val_loss: 0.7329 - val_acc: 0.5356
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 200/200 [==============================] - 8s 39ms/step - loss: 0.6806 - acc: 0.6256 - val_loss: 0.7553 - val_acc: 0.5219
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 200/200 [==============================] - 8s 40ms/step - loss: 0.7665 - acc: 0.6200 - val_loss: 0.7393 - val_acc: 0.5469
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 200/200 [==============================] - 8s 40ms/step - loss: 0.7429 - acc: 0.6088 - val_loss: 0.7822 - val_acc: 0.5319
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 200/200 [==============================] - 8s 40ms/step - loss: 0.6810 - acc: 0.5894 - val_loss: 0.6704 - val_acc: 0.5800
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7073 - acc: 0.6462 - val_loss: 0.7482 - val_acc: 0.5250
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 200/200 [==============================] - 8s 38ms/step - loss: 0.7007 - acc: 0.6556 - val_loss: 0.7522 - val_acc: 0.5856
#
# Epoch 00020: val_acc did not improve

# %% [markdown]
# ## Validation

# %%
h = history.history
plt.plot(h["acc"], c = "b")
plt.plot(h["val_acc"], c = "r")

# %%
nn = load_model("C:\\Users\\Sam\\Desktop\\song authorship\\notebooks\\8-15  -  first drafts\\weights-improvement-07-0.6031.h5")

# %%
rprd = nn.predict(rtest)
nprd = nn.predict(ntest)

# %%
from sklearn.metrics import confusion_matrix

# %%
c_mat = confusion_matrix(
    [1 for _ in rprd] + [0 for _ in nprd],
    np.append(np.round(rprd), np.round(nprd))
)

# %%
1067 / sum(c_mat[:,1])
# Out:
# 0.11232761343299294
