# %%
import string
import numpy as np

# %%
vocab = list(string.ascii_lowercase)

# %%
def make_lyrics(vocab, low, high, num_songs, genre, prob):
    return [np.random.choice(vocab, 
                             np.random.randint(low, high), 
                             replace = True,
                             p = prob) for _ in range(num_songs)]

# %%
popprob = np.array(list(range(1, 27))) / sum(list(range(1, 27)))
rapprob = popprob[::-1]
pop = make_lyrics(vocab, 100, 400, 100, "pop", popprob)
rap = make_lyrics(vocab, 100, 400, 100, "rap", rapprob)

# %%
def hellinger_distance(dist1, dist2):
    
    num = 0
    
    for element in dist1.keys():
        
        num += (np.sqrt(dist1[element]) - np.sqrt(dist2[element])) ** 2
        
    num = (1 / np.sqrt(2)) * np.sqrt(num)
    
    return 1 - num

# %%
def kl_divergence(dist1, dist2):
    
    num = 0
    
    for element in dist1.keys():
        if (dist2[element] == 0) and (dist1[element] == 0):
            continue
        num -= dist1[element] * np.log(dist2[element] / dist1[element])
        
    return num

# %%
def get_p_genre(x):
    return {genre:len(x[genre]) for genre in x}

# %%
def get_word_distribution(d, type_ = "train"):
    """
    if train: return word distribution
    if test: return each testing example's word distribution.
    """
    
    from collections import Counter
    from itertools import chain
    
    if type_ == "train":
        ans = Counter(list(chain.from_iterable(d)))
        norm = sum(ans.values())
        for element in ans:
            ans[element] /= norm

    elif type_ == "test":
        
        ans = []
        for song in d:
            ans1 = Counter(list(chain.from_iterable(song)))
            norm = sum(ans1.values())
            for element in ans1:
                ans1[element] /= norm 
            ans.append(ans1)
            
            
    return ans

# %%
popdist = get_word_distribution(pop)
rapdist = get_word_distribution(rap)

# %%
dists = {"pop": popdist, "rap": rapdist}

# %% [markdown]
# ### Make testing data

# %%
poptest = make_lyrics(vocab, 100, 400, 100, "pop", popprob)
raptest = make_lyrics(vocab, 100, 400, 100, "rap", rapprob)

# %%
poptest2 = get_word_distribution(poptest, "test")
raptest2 = get_word_distribution(raptest, "test")

# %%
def classify(data, dists, popprop, rapprop):
    p_genre = {"pop": popprop, "rap": rapprop}
    results = []
    for song in data:
        distance = {}
        for dist in dists:
            distance.update({dist: hellinger_distance(song, dists[dist]) * p_genre[dist]})
        #print(distance)
        results.append(max(distance.items(), key = lambda x: x[1]))
    return results

# %%
classify(raptest2, dists, .5, .5)
# Out:
# [('rap', 0.4351242125069986),
#  ('rap', 0.4490287380253664),
#  ('rap', 0.45484155288819605),
#  ('rap', 0.44066608941916113),
#  ('rap', 0.46113144976683973),
#  ('rap', 0.45405666600937045),
#  ('rap', 0.4482152290004212),
#  ('rap', 0.45424254340173115),
#  ('rap', 0.4491323467620527),
#  ('rap', 0.4438252259269708),
#  ('rap', 0.4485650780617269),
#  ('rap', 0.4432961710394042),
#  ('rap', 0.45487781934769167),
#  ('rap', 0.41828193434798877),
#  ('rap', 0.43582176716342536),
#  ('rap', 0.42950211493431384),
#  ('rap', 0.43304547993131165),
#  ('rap', 0.4253836283675927),
#  ('rap', 0.455586482420802),
#  ('rap', 0.43830533988510134),
#  ('rap', 0.44723808482438765),
#  ('rap', 0.46350439795806353),
#  ('rap', 0.42905616612187286),
#  ('rap', 0.4571593469722843),
#  ('rap', 0.44517502757134897),
#  ('rap', 0.4515025899614402),
#  ('rap', 0.45650833333164986),
#  ('rap', 0.44632357252118116),
#  ('rap', 0.43881655592728275),
#  ('rap', 0.45449840945118214),
#  ('rap', 0.42609449528347665),
#  ('rap', 0.46243180877508017),
#  ('rap', 0.44078033923494975),
#  ('rap', 0.4289738753335868),
#  ('rap', 0.442955479122206),
#  ('rap', 0.4509722731461383),
#  ('rap', 0.4357562862185537),
#  ('rap', 0.45748780446685233),
#  ('rap', 0.4378701544587496),
#  ('rap', 0.44960334272237384),
#  ('rap', 0.45491011048639307),
#  ('rap', 0.4238289884899977),
#  ('rap', 0.4431053001898465),
#  ('rap', 0.4563969447325804),
#  ('rap', 0.4358675354990279),
#  ('rap', 0.44825075387653623),
#  ('rap', 0.444031056496348),
#  ('rap', 0.44934650864730896),
#  ('rap', 0.45083605887755657),
#  ('rap', 0.42109114204427733),
#  ('rap', 0.44737573379273055),
#  ('rap', 0.4367740110544061),
#  ('rap', 0.4294953062414722),
#  ('rap', 0.4526420580985536),
#  ('rap', 0.4255567702479522),
#  ('rap', 0.4365471595944146),
#  ('rap', 0.463375590618321),
#  ('rap', 0.4457547685870756),
#  ('rap', 0.4615279943105683),
#  ('rap', 0.4228683862964409),
#  ('rap', 0.4558541507967841),
#  ('rap', 0.4468855917052082),
#  ('rap', 0.42847535839041007),
#  ('rap', 0.4226477597875716),
#  ('rap', 0.4534978517637009),
#  ('rap', 0.4453366691265262),
#  ('rap', 0.45366131223813927),
#  ('rap', 0.43596174859989634),
#  ('rap', 0.44643246771169354),
#  ('rap', 0.4291255233287281),
#  ('rap', 0.45789706496545024),
#  ('rap', 0.44897373704542853),
#  ('rap', 0.44228756937318847),
#  ('rap', 0.4537748209321456),
#  ('rap', 0.42864254435605753),
#  ('rap', 0.448043439430202),
#  ('rap', 0.43699122596939194),
#  ('rap', 0.43192584292794745),
#  ('rap', 0.41832386293550305),
#  ('rap', 0.4513805299353638),
#  ('rap', 0.41511777154173407),
#  ('rap', 0.45283250031497396),
#  ('rap', 0.43517280843874184),
#  ('rap', 0.42560684417616046),
#  ('rap', 0.4486730863178829),
#  ('rap', 0.4291414472773682),
#  ('rap', 0.4471010108054822),
#  ('rap', 0.4593826574449389),
#  ('rap', 0.4631476655136323),
#  ('rap', 0.4566395601717953),
#  ('rap', 0.4226984205323492),
#  ('rap', 0.4127549834397011),
#  ('rap', 0.44037484028797613),
#  ('rap', 0.4554583283625795),
#  ('rap', 0.4409504909985407),
#  ('rap', 0.4431709888428758),
#  ('rap', 0.4260865524552039),
#  ('rap', 0.43303008679646987),
#  ('rap', 0.45015158432374686),
#  ('rap', 0.44628026046615926)]

# %%
classify(poptest2, dists, .5, .5)
# Out:
# [('pop', 0.4323473959990164),
#  ('pop', 0.4439754774436474),
#  ('pop', 0.4503772662437322),
#  ('pop', 0.4499180225940682),
#  ('pop', 0.4515195707936297),
#  ('pop', 0.45382328546653794),
#  ('pop', 0.4352443617056324),
#  ('pop', 0.42940367460459494),
#  ('pop', 0.44667828104420604),
#  ('pop', 0.44031758593713),
#  ('pop', 0.42902918351977426),
#  ('pop', 0.4236125422207174),
#  ('pop', 0.45400431326752083),
#  ('pop', 0.44698513998651834),
#  ('pop', 0.45177615802295606),
#  ('pop', 0.45019886913320833),
#  ('pop', 0.4585059085127261),
#  ('pop', 0.42175285463710765),
#  ('pop', 0.42554366221083406),
#  ('pop', 0.4483736671321149),
#  ('pop', 0.43158344920400726),
#  ('pop', 0.44175531735793905),
#  ('pop', 0.46346698473083436),
#  ('pop', 0.46277985180358727),
#  ('pop', 0.4327407543061326),
#  ('pop', 0.45088290992817504),
#  ('pop', 0.4521496419581152),
#  ('pop', 0.45543424742493926),
#  ('pop', 0.45682822410292706),
#  ('pop', 0.45240417791766613),
#  ('pop', 0.44691582373120076),
#  ('pop', 0.42070970199182667),
#  ('pop', 0.45926552994753733),
#  ('pop', 0.45218235855425165),
#  ('pop', 0.4514927007640242),
#  ('pop', 0.423422722352692),
#  ('pop', 0.4283902529658602),
#  ('pop', 0.4309871507463744),
#  ('pop', 0.42339135565912095),
#  ('pop', 0.4479930509472405),
#  ('pop', 0.4378082809238794),
#  ('pop', 0.44811801837255355),
#  ('pop', 0.4271660764733669),
#  ('pop', 0.42819901554382966),
#  ('pop', 0.4337452644941529),
#  ('pop', 0.4396206718539247),
#  ('pop', 0.4538511276021352),
#  ('pop', 0.4525562185946068),
#  ('pop', 0.43851357027114624),
#  ('pop', 0.4260097232857454),
#  ('pop', 0.42725256824089874),
#  ('pop', 0.44944616019917566),
#  ('pop', 0.4424433865694569),
#  ('pop', 0.43856942652094294),
#  ('pop', 0.44396663819879806),
#  ('pop', 0.42754798549687795),
#  ('pop', 0.3924741895081449),
#  ('pop', 0.4573713284600048),
#  ('pop', 0.44846342129608563),
#  ('pop', 0.45396272776270197),
#  ('pop', 0.44838294631163084),
#  ('pop', 0.4524716437439651),
#  ('pop', 0.443453631046396),
#  ('pop', 0.4510776912080582),
#  ('pop', 0.4320118105935968),
#  ('pop', 0.43206395209567794),
#  ('pop', 0.44488419264322504),
#  ('pop', 0.459169499668119),
#  ('pop', 0.4462212401598062),
#  ('pop', 0.43876876233439455),
#  ('pop', 0.4656241781346152),
#  ('pop', 0.45252895877992555),
#  ('pop', 0.45557764797694433),
#  ('pop', 0.436912855821604),
#  ('pop', 0.44378409725650647),
#  ('pop', 0.4285952195618467),
#  ('pop', 0.44430036452730576),
#  ('pop', 0.42798168366414546),
#  ('pop', 0.44662600075736775),
#  ('pop', 0.4558340704725942),
#  ('pop', 0.4313997202944586),
#  ('pop', 0.4610060306200811),
#  ('pop', 0.4443672020858117),
#  ('pop', 0.4496846469754398),
#  ('pop', 0.4490911423531606),
#  ('pop', 0.44573335133270353),
#  ('pop', 0.4512092095196238),
#  ('pop', 0.44577410653292476),
#  ('pop', 0.4409720203740013),
#  ('pop', 0.44718107097711135),
#  ('pop', 0.4409577902384038),
#  ('pop', 0.4338060899912473),
#  ('pop', 0.4517692008258601),
#  ('pop', 0.4383899764020461),
#  ('pop', 0.45068142376119336),
#  ('pop', 0.45353002494364497),
#  ('pop', 0.44978963112855885),
#  ('pop', 0.42098227262495186),
#  ('pop', 0.44472454878926077),
#  ('pop', 0.4407674313347688)]
