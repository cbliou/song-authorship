# %%
import sys
sys.path.insert(0, "..//..//..//scripts")

import re
import matplotlib.pyplot as plt
import CDFClassifier

from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv("..//..//..//..//data//Weekly_data_tokenized.csv")

# %%
def create_genre(row, genre):
    if re.search(genre, row["Genre"], flags = re.I) != None:
        return 1
    else:
        return 0

df["Pop"] = df.apply(lambda row: create_genre(row, "pop"), axis = 1)
df["Rap"] = df.apply(lambda row: create_genre(row, "rap"), axis = 1)

df = df[["word", "ID", "Pop", "Rap"]]

# %%
np.random.seed(1)

IDs = df.ID.unique()
np.random.shuffle(IDs)

train = df[df.ID.isin(IDs[:int(.8 * len(IDs))])]
test = df[df.ID.isin(IDs[int(.8 * len(IDs)):])]

# %%
def grid_search(x, y, num, clf, train, test, classes, type_):
    
    grid = {}

    for n in np.linspace(x, y, num):
        tclf = clf(n, type_)
        tclf.fit(train, classes)
        grid.update({n: confusion_matrix(tclf.predict(test, classes), tclf.test_Y).ravel()})

    plt.plot([i for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])

# %%
grid_search(0.01, 2, 100, CDFClassifier, train, test, ["Pop", "Rap"], "Mann-Whitney")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-135-39a3786b2438> in <module>
# ----> 1 grid_search(0.01, 2, 100, CDFClassifier, train, test, ["Pop", "Rap"], "Mann-Whitney")
#
# <ipython-input-132-225bef20b8db> in grid_search(x, y, num, clf, train, test, classes, type_)
#       6         tclf = clf(n, type_)
#       7         tclf.fit(train, classes)
# ----> 8         grid.update({n: confusion_matrix(tclf.predict(test, classes), tclf.test_Y).ravel()})
#       9
#      10     plt.plot([i for i in grid], [(grid[i][0] + grid[i][-1]) / sum(grid[i]) for i in grid])
#
# <ipython-input-68-b289b8d52793> in predict(self, df, classes)
#     124
#     125         predicted = []
# --> 126         self.create_training_data(df, classes)
#     127
#     128         for example in self.test_X:
#
# <ipython-input-68-b289b8d52793> in create_training_data(self, df, classes)
#      85         for cls in classes:
#      86             for song in df.ID.unique():
# ---> 87                 counts = Counter(df[(df.ID == song) & (df[cls] == 1)].word)
#      88                 if len(counts) == 0:
#      89                     continue
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1165             if method is not None:
#    1166                 with np.errstate(all='ignore'):
# -> 1167                     result = method(y)
#    1168                 if result is NotImplemented:
#    1169                     raise TypeError("invalid type comparison")
#
# KeyboardInterrupt:

# %%
np.random.seed(1)

IDs = df.ID.unique()
np.random.shuffle(IDs)

train = df[df.ID.isin(IDs[:int(.8 * len(IDs))])]
test = df[df.ID.isin(IDs[int(.8 * len(IDs)):])]

poptrain = train[train["Pop"] == 1].word
raptrain = train[train["Rap"] == 1].word

poptest = test[test["Pop"] == 1]
raptest = test[test["Rap"] == 1]

poptraindist = get_word_distribution(poptrain)
poptraincdf = get_cdf(poptrain)
raptraindist = get_word_distribution(raptrain)
raptraincdf = get_cdf(raptrain)

dists = {"pop": poptraindist, "rap": raptraindist}
cdfs = {"pop": poptraincdf, "rap": raptraincdf}

poptestdist = get_word_distribution(poptest, "test")
raptestdist = get_word_distribution(raptest, "test")

numpop = len(train[train.Pop == 1].ID.unique())
numrap = len(train[train.Rap == 1].ID.unique())
popprop = numpop / (numpop + numrap)
rapprop = 1 - popprop
p_genre = {"pop": popprop, "rap": rapprop}

# %%
test = 43

# %%
tmp = get_order(raptraincdf, raptestdist[test])
sum(np.diff(tmp) > 0)
# Out:
# 67
